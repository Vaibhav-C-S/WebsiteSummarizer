# %% [markdown]
# ## Imports

# %%
import requests
from dotenv import load_dotenv
import os
from bs4 import BeautifulSoup
from openai import OpenAI

# %% [markdown]
# ## LOADING THE API

# %%
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if not api_key:
    raise Exception('OPENAI_API_KEY not found in .env')
print("api key found")
# Out:
# api key found

# %% [markdown]
# ## CREATE AN OPENAI INSTANCE

# %%
openai = OpenAI()

# %% [markdown]
# ## PREVIEW RESPONSE HOW TO FRONTIER MODEL

# %%
message = "What is the capital of France?"
response = openai.chat.completions.create(model="gpt-4o-mini",messages=[{"role": "user", "content": message}])

print(response.choices[0].message.content)
# Out:
# The capital of France is Paris.

# %%
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    def __init__(self,url):
        self.url = url
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

# %%
ed = Website("https://timesofindia.indiatimes.com/")
print(ed.title)
print(ed.text)
# Out:
# News - Latest News, Election Results, Breaking News, Bollywood, Sports, Business and Political News | Times of India
# Edition
# IN
# IN
# US
# Wed, Jan 29, 2025 | Updated 07.50PM IST
# Sign In
# TOI+
# TOI Games
# Budget 2025
# Videos
# City
# Metro Cities
# mumbai
# delhi
# bengaluru
# Hyderabad
# kolkata
# chennai
# Other Cities
# City
# agra
# agartala
# ahmedabad
# ajmer
# amaravati
# amritsar
# bareilly
# bhubaneswar
# bhopal
# chandigarh
# chhatrapati sambhajinagar
# coimbatore
# cuttack
# dehradun
# erode
# faridabad
# ghaziabad
# goa
# gurgaon
# guwahati
# hubballi
# imphal
# indore
# itanagar
# jaipur
# jammu
# jamshedpur
# jodhpur
# kanpur
# kochi
# kohima
# kolhapur
# kozhikode
# ludhiana
# lucknow
# madurai
# mangaluru
# meerut
# mumbai region
# mysuru
# nagpur
# nashik
# navi mumbai
# noida
# patna
# prayagraj
# puducherry
# pune
# raipur
# rajkot
# ranchi
# thane
# salem
# shillong
# shimla
# srinagar
# surat
# trichy
# thiruvananthapuram
# udaipur
# vadodara
# ...

# %% [markdown]
# User Prompt: The actual input or question given by the user to the AI (e.g., "Explain recursion in Python.").
#
#
# System Prompt: A hidden instruction that defines the AI's behavior, tone, or personality (e.g., "You are a helpful coding assistant.").

# %%
system_prompt = "You are an assistant that analyzes the contents of a website \
and provides a short summary, ignoring text that might be navigation related. \
Respond in markdown."

# %%
def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(website)}
    ]

# %%
def user_prompt_for(website):
    user_prompt = f"You are looking at a website titled {website.title}"
    user_prompt += "\nThe contents of this website is as follows; \
please provide a short summary of this website in markdown. \
If it includes news or announcements, then summarize these too.\n\n"
    user_prompt += website.text
    return user_prompt

# %%
def summarize(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model = "gpt-4o-mini",
        messages = messages_for(website)
    )
    return response.choices[0].message.content

# %%
def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
from IPython.display import Markdown, display

# %%
display_summary("https://timesofindia.indiatimes.com/")
# Out:
# # Times of India - News Summary
#
# The Times of India website provides a broad range of news coverage, including political updates, sports, entertainment, and business news. Key topics highlighted recently include:
#
# ## Major News Events
# - **Maha Kumbh Stampede:**
#   - A tragic stampede occurred during the Maha Kumbh Mela in Prayagraj, resulting in 30 fatalities and 60 injuries. UP's Chief Minister has expressed deep remorse and initiated an investigation into the incident. Police have set up helplines and are working to manage the situation.
#
# - **Delhi Water Controversy:**
#   - Arvind Kejriwal challenged PM Modi to drink water from the Yamuna river, emphasizing ongoing political tensions between Delhi's AAP and the BJP.
#
# - **US News:**
#   - Donald Trump faced backlash after taking controversial actions regarding immigration programs and foreign aid changes.
#
# ## Business and Economic Updates
# - **Budget 2025 Expectations:**
# ...
